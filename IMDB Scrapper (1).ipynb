# %%
import pandas as pd

sci_df = pd.read_csv('science data.csv')

# %%
sci_df.head()
# Out:
#            name  year movie_rated run_length                       genres  \
# 0     Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 1    The Matrix  1999           R   2h 16min             Action; Sci-Fi;
# 2  Interstellar  2014       PG-13   2h 49min   Adventure; Drama; Sci-Fi;
# 3  The Avengers  2012       PG-13   2h 23min  Action; Adventure; Sci-Fi;
# 4  The Prestige  2006       PG-13   2h 10min     Drama; Mystery; Sci-Fi;
#
#             release_date  rating  num_raters  num_reviews  \
# 0     16 July 2010 (USA)     8.8     1981688         3820
# 1    31 March 1999 (USA)     8.7     1619772         4281
# 2  7 November 2014 (USA)     8.6     1430810         3977
# 3       4 May 2012 (USA)     8.0     1236053         1929
# 4  20 October 2006 (USA)     8.5     1144521         1394
#
#                                           review_url  \
# 0  https://www.imdb.com/title/tt1375666/reviews/_...
# 1  https://www.imdb.com/title/tt0133093/reviews/_...
# 2  https://www.imdb.com/title/tt0816692/reviews/_...
# 3  https://www.imdb.com/title/tt0848228/reviews/_...
# 4  https://www.imdb.com/title/tt0482571/reviews/_...
#
#                                            Image Url
# 0  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...
# 1  https://resizing.flixster.com/q1aWnhA588SmGiAh...
# 2  https://resizing.flixster.com/kTXJKgfGpAcaD-4m...
# 3  https://resizing.flixster.com/4QmGJFR39jMm8uYS...
# 4  https://resizing.flixster.com/qjfK-2eY2kZA0EdC...

# %%
sci_list = sci_df.values.tolist()

# %%
sci_list
# Out:
# [['Inception',
#   2010,
#   'PG-13',
#   '2h 28min',
#   'Action; Adventure; Sci-Fi; ',
#   '16 July 2010 (USA)',
#   8.8,
#   1981688,
#   3820,
#   'https://www.imdb.com/title/tt1375666/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/8X8J8sNXmCWDBaxo3vueONLRj00=/206x305/v2/https://flxt.tmsimg.com/assets/p7825626_p_v8_af.jpg'],
#  ['The Matrix',
#   1999,
#   'R',
#   '2h 16min',
#   'Action; Sci-Fi; ',
#   '31 March 1999 (USA)',
#   8.7,
#   1619772,
#   4281,
#   'https://www.imdb.com/title/tt0133093/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/q1aWnhA588SmGiAht_9L3KXFUMA=/206x305/v2/https://flxt.tmsimg.com/assets/p22804_p_v8_av.jpg'],
#  ['Interstellar',
#   2014,
#   'PG-13',
#   '2h 49min',
#   'Adventure; Drama; Sci-Fi; ',
#   '7 November 2014 (USA)',
#   8.6,
#   1430810,
#   3977,
#   'https://www.imdb.com/title/tt0816692/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/kTXJKgfGpAcaD-4mPemzR7CyDwQ=/206x305/v2/https://flxt.tmsimg.com/assets/p10543523_p_v12_ar.jpg'],
#  ['The Avengers',
#   2012,
#   'PG-13',
#   '2h 23min',
#   'Action; Adventure; Sci-Fi; ',
#   '4 May 2012 (USA)',
#   8.0,
#   1236053,
#   1929,
#   'https://www.imdb.com/title/tt0848228/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/4QmGJFR39jMm8uYSeMv4Aop8w6I=/206x305/v2/https://flxt.tmsimg.com/assets/p8815512_p_v8_ax.jpg'],
#  ['The Prestige',
#   2006,
#   'PG-13',
#   '2h 10min',
#   'Drama; Mystery; Sci-Fi; ',
#   '20 October 2006 (USA)',
#   8.5,
#   1144521,
#   1394,
#   'https://www.imdb.com/title/tt0482571/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/qjfK-2eY2kZA0EdCwRDxxCczmec=/206x305/v2/https://flxt.tmsimg.com/assets/p161581_p_v8_aa.jpg'],
#  ['Back to the Future',
#   1985,
#   'PG',
#   '1h 56min',
#   'Adventure; Comedy; Sci-Fi; ',
#   '3 July 1985 (USA)',
#   8.5,
#   1015026,
#   1176,
#   'https://www.imdb.com/title/tt0088763/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/hhtSV1bY3QFAqgdNXNRuJ5Lu8bM=/206x305/v2/https://flxt.tmsimg.com/NowShowing/46432/46432_aa.jpg'],
#  ['V for Vendetta',
#   2005,
#   'R',
#   '2h 12min',
#   'Action; Drama; Sci-Fi; ',
#   '17 March 2006 (USA)',
#   8.2,
#   1002950,
#   2205,
#   'https://www.imdb.com/title/tt0434409/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/jnowzdBBav46HnbZrD57fflVfbo=/206x305/v2/https://flxt.tmsimg.com/assets/p159693_p_v8_av.jpg'],
#  ['Terminator 2: Judgment Day',
#   1991,
#   'R',
#   '2h 17min',
#   'Action; Sci-Fi; ',
#   '3 July 1991 (USA)',
#   8.5,
#   968511,
#   1269,
#   'https://www.imdb.com/title/tt0103064/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/6qXCimMpku_RGklH4Slc_Cm6mSg=/206x305/v2/https://flxt.tmsimg.com/assets/p13308_p_v8_ag.jpg'],
#  ['Iron Man',
#   2008,
#   'PG-13',
#   '2h 6min',
#   'Action; Adventure; Sci-Fi; ',
#   '2 May 2008 (USA)',
#   7.9,
#   915644,
#   1319,
#   'https://www.imdb.com/title/tt0371746/reviews/_ajax?ref_=undefined&paginationKey=',
#   'https://resizing.flixster.com/jTU4RAjnwcZAconup5QZkH2Emb8=/206x305/v2/https://flxt.tmsimg.com/assets/p170620_p_v8_az.jpg']]

# %%
# import requests

# def parsePage(URL):
#     page = requests.get(URL)

#     print(page.text)
#     return page.text

# %%
# for i in movie_list:
#     print("{} : {}".format(cnt,i[9]))

# page = parsePage(movie_list[0][9])
# print(page)
# # page_text =

# %%
import requests
from bs4 import BeautifulSoup

ratings_col = []
keywords_col = []
review_date_col = []
review_text_col = []

name = []
year = []
movie_rated = []
run_length = []
genres = []
release_date = []
IMDB_rating = []
num_raters = []
num_reviews = []
review_url =[]
image_Url = []


cnt = 0
for mv in sci_list:   
    cnt+=1
    print("{} : {}".format(cnt,mv[9]))
    page = requests.get(mv[9])
    soup = BeautifulSoup(page.content, "html.parser")
    
    job_elements = soup.find_all("div",{'class': 'lister-item-content'})
    i = 0; 
    for job_element in job_elements:
        i+=1
        name.append(mv[0])
        year.append(mv[1])
        movie_rated.append(mv[2])
        run_length.append(mv[3])
        genres.append(mv[4])
        release_date.append(mv[5])
        IMDB_rating.append(mv[6])
        num_raters.append(mv[7])
        num_reviews.append(mv[8])
        review_url.append(mv[9])
        image_Url.append(mv[10])
        rate = job_element.find("span",{'class': ''})
    #     print("{}".format(rate.text.strip()))
        if(len(rate.text.strip())<=2):
            ratings_col.append(int(rate.text))
    #         print(rate.text.strip())
        else:
            ratings_col.append(0)
    #         print(0)

        Keywords = job_element.find("a",{'class': 'title'})
#         i=i+1
        keywords_col.append(Keywords.text.strip())
#         print("{} : {}".format(i,Keywords.text.strip()))

        review_date = job_element.find("span",{'class': 'review-date'})
    #     i=i+1
        review_date_col.append(review_date.text.strip())
    #     print("{} : {}".format(i,review_date.text.strip()))

        review_text = job_element.find("div",{'class': 'text show-more__control'})
    #     i=i+1
        review_text_col.append(review_text.text.strip())
    #     print("{} : {}".format(i,review_text.text.strip()),end="\n"*2)

    #     print(job_element, end="\n"*2)
# Out:
# 1 : https://www.imdb.com/title/tt1375666/reviews/_ajax?ref_=undefined&paginationKey=
# 2 : https://www.imdb.com/title/tt0133093/reviews/_ajax?ref_=undefined&paginationKey=
# 3 : https://www.imdb.com/title/tt0816692/reviews/_ajax?ref_=undefined&paginationKey=
# 4 : https://www.imdb.com/title/tt0848228/reviews/_ajax?ref_=undefined&paginationKey=
# 5 : https://www.imdb.com/title/tt0482571/reviews/_ajax?ref_=undefined&paginationKey=
# 6 : https://www.imdb.com/title/tt0088763/reviews/_ajax?ref_=undefined&paginationKey=
# 7 : https://www.imdb.com/title/tt0434409/reviews/_ajax?ref_=undefined&paginationKey=
# 8 : https://www.imdb.com/title/tt0103064/reviews/_ajax?ref_=undefined&paginationKey=
# 9 : https://www.imdb.com/title/tt0371746/reviews/_ajax?ref_=undefined&paginationKey=

# %%
job_elements = soup.find_all("div",{'class': 'lister-item-content'})
i = 0; 
for job_element in job_elements:
    rate = job_element.find("span",{'class': ''})
#     print("{}".format(rate.text.strip()))
    if(len(rate.text.strip())<=2):
        ratings_col.append(int(rate.text))
#         print(rate.text.strip())
    else:
        ratings_col.append(0)
#         print(0)
    
    Keywords = job_element.find("a",{'class': 'title'})
    i=i+1
    keywords_col.append(Keywords.text.strip())
    print("{} : {}".format(i,Keywords.text.strip()))
    
    review_date = job_element.find("span",{'class': 'review-date'})
#     i=i+1
    review_date_col.append(review_date.text.strip())
#     print("{} : {}".format(i,review_date.text.strip()))
    
    review_text = job_element.find("div",{'class': 'text show-more__control'})
#     i=i+1
    review_text_col.append(review_text.text.strip())
#     print("{} : {}".format(i,review_text.text.strip()),end="\n"*2)
    
#     print(job_element, end="\n"*2)
# Out:
# 1 : Considering I am not much of a fan of superhero movies, this one is a success
# 2 : A Marvel superhero film done with class
# 3 : Iron Man Eats His Spinach
# 4 : Scrapheap Challenge is more entertaining
# 5 : Very Good
# 6 : RDJ is Iron Man
# 7 : No Iron! How Ironic!
# 8 : interesting
# 9 : How it all began
# 10 : Entertaining and Totally Overrated in IMDb
# 11 : Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster
# 12 : Great performances
# 13 : "So you're a man who has everything,..., and nothing."
# 14 : believe it or not, I'd never heard of Iron Man before this movie came out
# 15 : Far Exceeds The Character's Usual Presentation
# 16 : Iron Man
# 17 : A solid introduction to the Iron man character
# 18 : A Fun Two Hours Of Nonsense
# 19 : You'll believe an Iron Man can fly!
# 20 : Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.
# 21 : supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre
# 22 : Iron Man is an exciting beginning for the summer movie season
# 23 : Iron Man Meets its Mettle **1/2
# 24 : Disappointing script, sparse action scenes
# 25 : Genuine blockbuster.

# %%
import pandas as pd

data = {
    "name" : pd.Series(name),
    "year" :pd.Series(year),
    "movie_rated" :pd.Series(movie_rated),
    "run_length" :pd.Series(run_length),
    "genres":pd.Series(genres),
    "release_date":pd.Series(release_date),
    "IMDB_rating":pd.Series(IMDB_rating),
    "num_raters":pd.Series(num_raters),
    "num_reviews":pd.Series(num_reviews),
    "review_url":pd.Series(review_url),
    "image_Url":pd.Series(image_Url),
    "rating": pd.Series(ratings_col),
    "keyword": pd.Series(keywords_col),
    "review_date" : pd.Series(review_date_col),
    "review" : pd.Series(review_text_col)
}

# pd.DataFrame({'a': pd.Series(a), 'b': pd.Series(b)})

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df.head()) 
df.to_csv(r'D:\Sentiment analytics\Assignment3\science data.csv', index = None, header=True)
# Out:
#         name    year movie_rated run_length                       genres  \
# 0  Inception  2010.0       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 1  Inception  2010.0       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 2  Inception  2010.0       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 3  Inception  2010.0       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 4  Inception  2010.0       PG-13   2h 28min  Action; Adventure; Sci-Fi;
#
#          release_date  IMDB_rating  num_raters  num_reviews  \
# 0  16 July 2010 (USA)          8.8   1981688.0       3820.0
# 1  16 July 2010 (USA)          8.8   1981688.0       3820.0
# 2  16 July 2010 (USA)          8.8   1981688.0       3820.0
# 3  16 July 2010 (USA)          8.8   1981688.0       3820.0
# 4  16 July 2010 (USA)          8.8   1981688.0       3820.0
#
#                                           review_url  \
# 0  https://www.imdb.com/title/tt1375666/reviews/_...
# 1  https://www.imdb.com/title/tt1375666/reviews/_...
# 2  https://www.imdb.com/title/tt1375666/reviews/_...
# 3  https://www.imdb.com/title/tt1375666/reviews/_...
# 4  https://www.imdb.com/title/tt1375666/reviews/_...
#
#                                            image_Url  rating  \
# 0  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 1  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       7
# 2  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       9
# 3  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 4  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
#
#                                              keyword      review_date  \
# 0  Amazingly original...but also a bit overwhelming.  2 December 2010
# 1           A good film, but not as good as the hype     5 March 2011
# 2                                         Dream Team     21 July 2010
# 3    A Hollywood rarity - an intelligent action film    4 August 2016
# 4           Not Your Typical, Brainless Summer Movie     23 July 2010
#
#                                               review
# 0  This review is being written by a 46 year-old ...
# 1  I heard a number of great things about Incepti...
# 2  Watching Inception with its futuristic emphasi...
# 3  Christopher Nolan is a director to be applaude...
# 4  Inception (2010) *** 1/2 (out of 4)The "kiss" ...
