# %%
import pandas as pd

# %%
sentimental_df = pd.read_csv(r'D:\Sentiment analytics\Assignment3\science data.csv')

# %%
# sentimental_df = sentimental_df.iloc[0:100,:]

# %%
sentimental_df.shape
# Out:
# (250, 16)

# %%
sentimental_df.head()
# Out:
#    Sr.no       name  year movie_rated run_length                       genres  \
# 0      1  Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 1      2  Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 2      3  Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 3      4  Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
# 4      5  Inception  2010       PG-13   2h 28min  Action; Adventure; Sci-Fi;
#
#          release_date  IMDB_rating  num_raters  num_reviews  \
# 0  16 July 2010 (USA)          8.8     1981688         3820
# 1  16 July 2010 (USA)          8.8     1981688         3820
# 2  16 July 2010 (USA)          8.8     1981688         3820
# 3  16 July 2010 (USA)          8.8     1981688         3820
# 4  16 July 2010 (USA)          8.8     1981688         3820
#
#                                           review_url  \
# 0  https://www.imdb.com/title/tt1375666/reviews/_...
# 1  https://www.imdb.com/title/tt1375666/reviews/_...
# 2  https://www.imdb.com/title/tt1375666/reviews/_...
# 3  https://www.imdb.com/title/tt1375666/reviews/_...
# 4  https://www.imdb.com/title/tt1375666/reviews/_...
#
#                                            image_Url  rating  \
# 0  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 1  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       7
# 2  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       9
# 3  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 4  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
#
#                                              keyword review_date  \
# 0  Amazingly original...but also a bit overwhelming.   02-Dec-10
# 1           A good film, but not as good as the hype   05-Mar-11
# 2                                         Dream Team   21-Jul-10
# 3    A Hollywood rarity - an intelligent action film   04-Aug-16
# 4           Not Your Typical, Brainless Summer Movie   23-Jul-10
#
#                                               review
# 0  This review is being written by a 46 year-old ...
# 1  I heard a number of great things about Incepti...
# 2  Watching Inception with its futuristic emphasi...
# 3  Christopher Nolan is a director to be applaude...
# 4  Inception (2010) *** 1/2 (out of 4)The "kiss" ...

# %%
sentimental_df["name"][0]
# Out:
# 'Inception'

# %%
sentiments = []

for i in range(0,len(sentimental_df)):
    review = {"id" : sentimental_df["Sr.no"][i],"text": sentimental_df["keyword"][i] }
    sentiments.append(review)

# %%
sentiments
# Out:
# [{'id': 1, 'text': 'Amazingly original...but also a bit overwhelming.'},
#  {'id': 2, 'text': 'A good film, but not as good as the hype'},
#  {'id': 3, 'text': 'Dream Team'},
#  {'id': 4, 'text': 'A Hollywood rarity - an intelligent action film'},
#  {'id': 5, 'text': 'Not Your Typical, Brainless Summer Movie'},
#  {'id': 6, 'text': 'Oozing with originality'},
#  {'id': 7, 'text': 'Come Back Again!'},
#  {'id': 8, 'text': 'labyrinth'},
#  {'id': 9, 'text': 'A deep dive into the human mind, Nolan at his finest'},
#  {'id': 10, 'text': 'Overrated Mess'},
#  {'id': 11,
#   'text': 'Not all the hype suggests but still an enjoyable action thriller built on a good concept and encourages thought afterwards'},
#  {'id': 12, 'text': 'Matrix light'},
#  {'id': 13, 'text': '(De-)Constructing'},
#  {'id': 14, 'text': '"...it\'s never just a dream, is it"?'},
#  {'id': 15, 'text': 'I have a dream'},
#  {'id': 16, 'text': 'Christopher Nolan is the Modern Directing Genius'},
#  {'id': 17, 'text': 'Inception'},
#  {'id': 18, 'text': 'Dreams within dreams'},
#  {'id': 19, 'text': 'Mind Boggling.'},
#  {'id': 20,
#   'text': 'Overwhelming and impressive movie with frantic action , suspenseful and state-of-art special effects'},
#  {'id': 21, 'text': 'Mind-boggling...'},
#  {'id': 22, 'text': 'The ultimate mind-f**k movie? Dream on.'},
#  {'id': 23, 'text': '"Take a leap of faith..."'},
#  {'id': 24,
#   'text': 'Totally novel story, I found that it took me several viewings to gain a good grasp of it.'},
#  {'id': 25, 'text': 'What is reality...what is a dream'},
#  {'id': 26,
#   'text': 'Too much action, too many stunts...yet still an interesting story idea.'},
#  {'id': 27, 'text': 'A sci-fi action thriller milestone'},
#  {'id': 28, 'text': 'Effects-fuelled sci-fi extravaganza'},
#  {'id': 29, 'text': 'Ultra cool sci-fi'},
#  {'id': 30, 'text': 'Wow! I Finally Saw It!'},
#  {'id': 31, 'text': 'a masterpiece'},
#  {'id': 32, 'text': 'Good? Yes. Groundbreaking? Not really.'},
#  {'id': 33, 'text': 'Life in reality'},
#  {'id': 34,
#   'text': 'Perfect sci-fi, great action and perfect plot for the internet loser generation (like me!)'},
#  {'id': 35, 'text': 'Blender'},
#  {'id': 36,
#   'text': '"...there\'s a difference between knowing the path... and walking the path".'},
#  {'id': 37, 'text': 'Watch the original, but not the sequels.'},
#  {'id': 38, 'text': 'The Matrix'},
#  {'id': 39, 'text': 'A cyberpunk classic'},
#  {'id': 40, 'text': 'A Bit Confusing But A Big F/X Treat'},
#  {'id': 41,
#   'text': 'Top-notch movie with impressive production design , marvelous effects and incredible visual designs'},
#  {'id': 42,
#   'text': 'A watchable action sci-fi movie that was and still is over-hyped...'},
#  {'id': 43, 'text': 'Whoa!'},
#  {'id': 44, 'text': '"After this, there is no turning back..."'},
#  {'id': 45,
#   'text': 'One of the best DVDs out so far, much more than just a movie!'},
#  {'id': 46, 'text': 'What the hell is the "Matrix?"'},
#  {'id': 47,
#   'text': 'One of the greatest achievements in Science-fiction film history'},
#  {'id': 48, 'text': 'Keanu Reeves in Wonderland'},
#  {'id': 49, 'text': 'A computer world Alice in Wonderland. Sci-fi greatness!'},
#  {'id': 50, 'text': 'Awesome sci-fi flick!'},
#  {'id': 51,
#   'text': 'Why tack on an ending where everything works out perfectly?!'},
#  {'id': 52,
#   'text': 'Often impressive and very beautiful, but less than stellar'},
#  {'id': 53, 'text': 'Another bloated, overrated space epic'},
#  {'id': 54, 'text': 'some problems but a few great touches of 2001'},
#  {'id': 55, 'text': 'Intellectual, Although Sometimes Flawed Science Fiction'},
#  {'id': 56,
#   'text': 'Maybe the most spectacular movie of 2014 and one of the best'},
#  {'id': 57, 'text': "It doesn't all work, but it is beautiful in its efforts"},
#  {'id': 58, 'text': 'START PULLING YOUR WEIGHT'},
#  {'id': 59, 'text': 'Out of this world'},
#  {'id': 60,
#   'text': '"We\'re not meant to save the world, we\'re meant to leave it."'},
#  {'id': 61, 'text': 'Absolutely Brilliant'},
#  {'id': 62, 'text': 'Interstellar'},
#  {'id': 63, 'text': 'A journey across the galaxy to save humanity'},
#  {'id': 64, 'text': 'Great up towards the end...'},
#  {'id': 65, 'text': 'Disappears up its own black hole.'},
#  {'id': 66,
#   'text': 'This is my kind of movie, Sci-Fi with a good story and lots of action.'},
#  {'id': 67,
#   'text': 'Interstellar is quite an intriguing space movie requiring some attention to the narrative'},
#  {'id': 68, 'text': 'Emotionally captivating and intellectually challenging'},
#  {'id': 69, 'text': "Absolutely thrilling! A can't miss movie!"},
#  {'id': 70, 'text': 'Dissymmetries, sight'},
#  {'id': 71, 'text': 'Worm-Holes ? What About Plot Holes ?'},
#  {'id': 72, 'text': 'Sometimes Dull and Overwritten but Worth a "Watch"'},
#  {'id': 73, 'text': 'Long, dull and WAY overpraised'},
#  {'id': 74, 'text': 'Gone To Earth'},
#  {'id': 75, 'text': 'When Earth Can No Longer Be Your Home'},
#  {'id': 76,
#   'text': 'The world loves it, though I still think the original "Iron Man", "Thor" and "Captain America" were my favorites.'},
#  {'id': 77,
#   'text': 'Not 100% perfect but still an outstanding film in so many ways'},
#  {'id': 78, 'text': 'Wanted to hate it, ended up loving it'},
#  {'id': 79, 'text': 'A Gem of an Action Movie'},
#  {'id': 80, 'text': 'Avengers vs TDKR'},
#  {'id': 81, 'text': "I'm Too Old for This!"},
#  {'id': 82, 'text': 'New York Geography'},
#  {'id': 83, 'text': 'A success yes, but not really on a groundbreaking level'},
#  {'id': 84, 'text': 'Avengers Assemble at once'},
#  {'id': 85, 'text': 'Excellent Adventure'},
#  {'id': 86,
#   'text': 'Consistently enjoyable effects and noise with the right amount of fun mixed in'},
#  {'id': 87,
#   'text': "If they can't save the box office, they sure as hell will avenge it"},
#  {'id': 88, 'text': '"The world has gotten stranger than you even know."'},
#  {'id': 89, 'text': 'Charlie Chaplin meets Lucy meets Jules'},
#  {'id': 90, 'text': 'Great Movie... But Not That Great'},
#  {'id': 91, 'text': 'Avengers Assemble'},
#  {'id': 92, 'text': 'Avengers Assemble'},
#  {'id': 93, 'text': 'More superheroes...'},
#  {'id': 94, 'text': 'What a load of Chitauri.'},
#  {'id': 95,
#   'text': '"We need a plan of attack." ... "I have a plan: attack!"'},
#  {'id': 96,
#   'text': "'Humans are unruly, and for that reason they cannot be ruled.'"},
#  {'id': 97, 'text': 'Fun, and great characters and dialog first and foremost'},
#  {'id': 98,
#   'text': "The Avengers is a nearly excellent first movie featuring Marvel's Earth's Mightiest Heroes"},
#  {'id': 99, 'text': 'A great blockbuster'},
#  {'id': 100, 'text': 'Marvel Comic heroes to the rescue!!'},
#  {'id': 101,
#   'text': "Some very interesting plot twists and originality, though it's a bit grim and lifeless"},
#  {'id': 102, 'text': 'Imperfect but fascinating'},
#  {'id': 103,
#   'text': 'A film that cheats the viewer - and I hated it for that'},
#  {'id': 104, 'text': 'Obsession and Revenge'},
#  {'id': 105, 'text': 'A Film with Intellect'},
#  {'id': 106, 'text': 'fascinating'},
#  {'id': 107, 'text': 'So glad this movie did not stay an illusion...'},
#  {'id': 108,
#   'text': 'A Great Tale of Rivalry, Obsession, Revenge and Sacrifice'},
#  {'id': 109,
#   'text': 'A very well told story despite the lack of shine in the final reveal (spoilers)'},
#  {'id': 110, 'text': '(Magic) Layers'},
#  {'id': 111, 'text': '"It is very rare to see... real magic."'},
#  {'id': 112, 'text': 'Batman and Alfred (outside Gotham) meet Wolverine'},
#  {'id': 113, 'text': 'Give This Film Time to Sink In...'},
#  {'id': 114, 'text': 'The Prestige'},
#  {'id': 115, 'text': 'Rivalry and obsession in the world of magic'},
#  {'id': 116, 'text': 'Never ask me about my business.'},
#  {'id': 117, 'text': 'Just As Intriguing The Second Time, Too!'},
#  {'id': 118,
#   'text': 'Imaginative and intriguing crash of wits between two famous magicians'},
#  {'id': 119, 'text': 'How many times can you double-cross your audience?'},
#  {'id': 120, 'text': "In 'magic' it's all about the third act! The Prestige."},
#  {'id': 121, 'text': "Obsession is a young man's game"},
#  {'id': 122,
#   'text': 'a basic tale of one-up-manship, but done in a great fashion of professional storytelling and acting'},
#  {'id': 123,
#   'text': 'The Prestige was interesting if maybe a little slow to wade through'},
#  {'id': 124, 'text': "The Prestige- Don't Need this Type of Honor 1/2*"},
#  {'id': 125, 'text': 'LOVED the trick with the canary!'},
#  {'id': 126, 'text': 'So good in so many ways'},
#  {'id': 127, 'text': "An '80s classic that never disappoints"},
#  {'id': 128, 'text': 'Wonderful story Wonderful Michael J Fox'},
#  {'id': 129, 'text': 'So Much Fun'},
#  {'id': 130, 'text': 'adorable'},
#  {'id': 131,
#   'text': 'Very entertaining film \x96 as slick as it is fun as it is engaging'},
#  {'id': 132, 'text': 'Marty got Back'},
#  {'id': 133, 'text': '"Yeah well, history is gonna change."'},
#  {'id': 134,
#   'text': "Many people may remember Michael J. Fox as Alex Keaton, but I'll always remember him as Marty McFly"},
#  {'id': 135, 'text': 'Gets Better With Age'},
#  {'id': 136, 'text': 'Back to the Future'},
#  {'id': 137, 'text': 'Great sci-fi adventure for all the family'},
#  {'id': 138, 'text': 'Amusing and commercial success.'},
#  {'id': 139, 'text': 'Mixed Emotions Looking Back On This Film Today'},
#  {'id': 140,
#   'text': 'Great Scott! Strap in for some entertaining time travel...'},
#  {'id': 141, 'text': 'A film you can watch time and time again.'},
#  {'id': 142, 'text': 'Great!'},
#  {'id': 143,
#   'text': 'Back To The Future, great start to the trilogy, movies in 1985, 1989, and 1990.'},
#  {'id': 144, 'text': 'Old Man Peabody owned all of this!'},
#  {'id': 145,
#   'text': 'After 30 years, the original Back to the Future is still the best of the series!'},
#  {'id': 146, 'text': 'A time travel movie that never gets old.'},
#  {'id': 147, 'text': 'Brilliant Scenario!'},
#  {'id': 148, 'text': 'Good fun'},
#  {'id': 149, 'text': 'A timeless classic'},
#  {'id': 150, 'text': 'Zemeckis Flies'},
#  {'id': 151, 'text': "Among the best stuff you'll see from DC Comics."},
#  {'id': 152, 'text': "Looks fantastic, but overall I just didn't care for it"},
#  {'id': 153, 'text': 'unreal Orwellian world'},
#  {'id': 154, 'text': 'to see it once'},
#  {'id': 155, 'text': 'Anonymous wants you'},
#  {'id': 156,
#   'text': 'Ideas Are Bulletproof and One Man Can Make the Difference'},
#  {'id': 157,
#   'text': 'A surprisingly effective social satire within a Hollywood film? It is not perfect but it is very enjoyable for what it does'},
#  {'id': 158, 'text': 'Behind the mask'},
#  {'id': 159,
#   'text': '"Then you have no fear anymore, you are completely free."'},
#  {'id': 160, 'text': "five'll get you ten"},
#  {'id': 161, 'text': 'One of Those Rare Films to Really Earn a 10'},
#  {'id': 162, 'text': 'V for Vendetta'},
#  {'id': 163, 'text': 'An Interesting Dystopia'},
#  {'id': 164,
#   'text': 'Intelligent film with political criticism , thrills , action and suspense'},
#  {'id': 165, 'text': 'V. Good!'},
#  {'id': 166,
#   'text': '"A revolution without dancing is a revolution not worth having."'},
#  {'id': 167, 'text': 'Superb movie of the graphic novel.'},
#  {'id': 168, 'text': "the first excellent film I've seen in 2006"},
#  {'id': 169,
#   'text': 'Winston Churchill Flashes No V Sign Here "V For Vendettal **1/2'},
#  {'id': 170, 'text': 'Exceeds expectations'},
#  {'id': 171, 'text': 'A revolution is in the grand plan.'},
#  {'id': 172, 'text': 'Eloquent'},
#  {'id': 173, 'text': 'Eye for Itself'},
#  {'id': 174,
#   'text': 'V for Vigilante\x85Stylish and Dark Film with Political Prognosis'},
#  {'id': 175,
#   'text': 'Really surprised at how much I liked this, why did it take me so long to watch it?'},
#  {'id': 176,
#   'text': 'A bigger, richer sequel that is every bit as fantastic as its predecessor and even surpasses it in some areas'},
#  {'id': 177, 'text': 'The purest form of action cinema there is'},
#  {'id': 178, 'text': 'Masterpiece Sci-Fi'},
#  {'id': 179, 'text': 'Great action and much more'},
#  {'id': 180, 'text': '"You can\'t just go around killing people!"'},
#  {'id': 181, 'text': "Here's why it outdoes the original:"},
#  {'id': 182, 'text': 'Best. Terminator. Movie. Ever.'},
#  {'id': 183, 'text': 'Terminator 2: Judgement Day'},
#  {'id': 184,
#   'text': 'The Terminator is back\x85 this time to save John Connor'},
#  {'id': 185, 'text': 'Many Annoyances, But An Incredible Action Flick'},
#  {'id': 186,
#   'text': 'Nail-biting and exhilarating outing with state-of-art special effects'},
#  {'id': 187, 'text': 'Come with me if you want to live!...'},
#  {'id': 188,
#   'text': 'You want incredible action and excitement? No problemo....'},
#  {'id': 189, 'text': 'surpasses the original'},
#  {'id': 190, 'text': 'Hasta la vista baby'},
#  {'id': 191, 'text': 'Over Produced and Over Rated Sequel'},
#  {'id': 192, 'text': "I'll be back"},
#  {'id': 193, 'text': 'An innovative trend-setter'},
#  {'id': 194, 'text': 'The Best Terminator Movie!!!'},
#  {'id': 195, 'text': 'Better than the original'},
#  {'id': 196, 'text': 'Come with me if you want to live.'},
#  {'id': 197, 'text': "There's a reason this is so appreciated"},
#  {'id': 198, 'text': "He's Baa-aack"},
#  {'id': 199, 'text': 'An observation'},
#  {'id': 200,
#   'text': '"Back" and better than ever! One of the best sequels in cinematic history.'},
#  {'id': 201,
#   'text': 'Considering I am not much of a fan of superhero movies, this one is a success'},
#  {'id': 202, 'text': 'A Marvel superhero film done with class'},
#  {'id': 203, 'text': 'Iron Man Eats His Spinach'},
#  {'id': 204, 'text': 'Scrapheap Challenge is more entertaining'},
#  {'id': 205, 'text': 'Very Good'},
#  {'id': 206, 'text': 'RDJ is Iron Man'},
#  {'id': 207, 'text': 'No Iron! How Ironic!'},
#  {'id': 208, 'text': 'interesting'},
#  {'id': 209, 'text': 'How it all began'},
#  {'id': 210, 'text': 'Entertaining and Totally Overrated in IMDb'},
#  {'id': 211,
#   'text': 'Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster'},
#  {'id': 212, 'text': 'Great performances'},
#  {'id': 213,
#   'text': '"So you\'re a man who has everything,..., and nothing."'},
#  {'id': 214,
#   'text': "believe it or not, I'd never heard of Iron Man before this movie came out"},
#  {'id': 215, 'text': "Far Exceeds The Character's Usual Presentation"},
#  {'id': 216, 'text': 'Iron Man'},
#  {'id': 217, 'text': 'A solid introduction to the Iron man character'},
#  {'id': 218, 'text': 'A Fun Two Hours Of Nonsense'},
#  {'id': 219, 'text': "You'll believe an Iron Man can fly!"},
#  {'id': 220,
#   'text': 'Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.'},
#  {'id': 221,
#   'text': "supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre"},
#  {'id': 222,
#   'text': 'Iron Man is an exciting beginning for the summer movie season'},
#  {'id': 223, 'text': 'Iron Man Meets its Mettle **1/2'},
#  {'id': 224, 'text': 'Disappointing script, sparse action scenes'},
#  {'id': 225, 'text': 'Genuine blockbuster.'},
#  {'id': 226,
#   'text': 'Considering I am not much of a fan of superhero movies, this one is a success'},
#  {'id': 227, 'text': 'A Marvel superhero film done with class'},
#  {'id': 228, 'text': 'Iron Man Eats His Spinach'},
#  {'id': 229, 'text': 'Scrapheap Challenge is more entertaining'},
#  {'id': 230, 'text': 'Very Good'},
#  {'id': 231, 'text': 'RDJ is Iron Man'},
#  {'id': 232, 'text': 'No Iron! How Ironic!'},
#  {'id': 233, 'text': 'interesting'},
#  {'id': 234, 'text': 'How it all began'},
#  {'id': 235, 'text': 'Entertaining and Totally Overrated in IMDb'},
#  {'id': 236,
#   'text': 'Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster'},
#  {'id': 237, 'text': 'Great performances'},
#  {'id': 238,
#   'text': '"So you\'re a man who has everything,..., and nothing."'},
#  {'id': 239,
#   'text': "believe it or not, I'd never heard of Iron Man before this movie came out"},
#  {'id': 240, 'text': "Far Exceeds The Character's Usual Presentation"},
#  {'id': 241, 'text': 'Iron Man'},
#  {'id': 242, 'text': 'A solid introduction to the Iron man character'},
#  {'id': 243, 'text': 'A Fun Two Hours Of Nonsense'},
#  {'id': 244, 'text': "You'll believe an Iron Man can fly!"},
#  {'id': 245,
#   'text': 'Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.'},
#  {'id': 246,
#   'text': "supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre"},
#  {'id': 247,
#   'text': 'Iron Man is an exciting beginning for the summer movie season'},
#  {'id': 248, 'text': 'Iron Man Meets its Mettle **1/2'},
#  {'id': 249, 'text': 'Disappointing script, sparse action scenes'},
#  {'id': 250, 'text': 'Genuine blockbuster.'}]

# %%
# sentimental_df['sentiments'] = sentiments

# %%
sentimental_df
# Out:
#      Sr.no       name  year movie_rated run_length  \
# 0        1  Inception  2010       PG-13   2h 28min
# 1        2  Inception  2010       PG-13   2h 28min
# 2        3  Inception  2010       PG-13   2h 28min
# 3        4  Inception  2010       PG-13   2h 28min
# 4        5  Inception  2010       PG-13   2h 28min
# ..     ...        ...   ...         ...        ...
# 245    246   Iron Man  2008       PG-13    2h 6min
# 246    247   Iron Man  2008       PG-13    2h 6min
# 247    248   Iron Man  2008       PG-13    2h 6min
# 248    249   Iron Man  2008       PG-13    2h 6min
# 249    250   Iron Man  2008       PG-13    2h 6min
#
#                           genres        release_date  IMDB_rating  num_raters  \
# 0    Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 1    Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 2    Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 3    Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 4    Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# ..                           ...                 ...          ...         ...
# 245  Action; Adventure; Sci-Fi;     2 May 2008 (USA)          7.9      915644
# 246  Action; Adventure; Sci-Fi;     2 May 2008 (USA)          7.9      915644
# 247  Action; Adventure; Sci-Fi;     2 May 2008 (USA)          7.9      915644
# 248  Action; Adventure; Sci-Fi;     2 May 2008 (USA)          7.9      915644
# 249  Action; Adventure; Sci-Fi;     2 May 2008 (USA)          7.9      915644
#
#      num_reviews                                         review_url  \
# 0           3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 1           3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 2           3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 3           3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 4           3820  https://www.imdb.com/title/tt1375666/reviews/_...
# ..           ...                                                ...
# 245         1319  https://www.imdb.com/title/tt0371746/reviews/_...
# 246         1319  https://www.imdb.com/title/tt0371746/reviews/_...
# 247         1319  https://www.imdb.com/title/tt0371746/reviews/_...
# 248         1319  https://www.imdb.com/title/tt0371746/reviews/_...
# 249         1319  https://www.imdb.com/title/tt0371746/reviews/_...
#
#                                              image_Url  rating  \
# 0    https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 1    https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       7
# 2    https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       9
# 3    https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 4    https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
# ..                                                 ...     ...
# 245  https://resizing.flixster.com/jTU4RAjnwcZAconu...      10
# 246  https://resizing.flixster.com/jTU4RAjnwcZAconu...       9
# 247  https://resizing.flixster.com/jTU4RAjnwcZAconu...       5
# 248  https://resizing.flixster.com/jTU4RAjnwcZAconu...       0
# 249  https://resizing.flixster.com/jTU4RAjnwcZAconu...       9
#
#                                                keyword review_date  \
# 0    Amazingly original...but also a bit overwhelming.   02-Dec-10
# 1             A good film, but not as good as the hype   05-Mar-11
# 2                                           Dream Team   21-Jul-10
# 3      A Hollywood rarity - an intelligent action film   04-Aug-16
# 4             Not Your Typical, Brainless Summer Movie   23-Jul-10
# ..                                                 ...         ...
# 245  supreme comic-book entertainment; it's also mo...   02-May-08
# 246  Iron Man is an exciting beginning for the summ...   12-May-08
# 247                    Iron Man Meets its Mettle **1/2   15-Nov-08
# 248         Disappointing script, sparse action scenes   25-Sep-08
# 249                               Genuine blockbuster.   03-May-08
#
#                                                 review
# 0    This review is being written by a 46 year-old ...
# 1    I heard a number of great things about Incepti...
# 2    Watching Inception with its futuristic emphasi...
# 3    Christopher Nolan is a director to be applaude...
# 4    Inception (2010) *** 1/2 (out of 4)The "kiss" ...
# ..                                                 ...
# 245  Iron Man is about as close to perfect popcorn ...
# 246  While I have long been a fan of various superh...
# 247  Action-pact thriller provides a field day for ...
# 248  This film is about a wealthy weapon developer ...
# 249  Iron Man is based on the fictional Marvel Comi...
#
# [250 rows x 16 columns]

# %%
reviews = sentiments

# %%
for review_num in range(len(reviews)):
    # print the review text
    print('{}\n{}\n\n\n\n\n'.format(reviews[review_num]['id'], reviews[review_num]['text']))
# Out:
# 1
# Amazingly original...but also a bit overwhelming.
#
#
#
#
#
# 2
# A good film, but not as good as the hype
#
#
#
#
#
# 3
# Dream Team
#
#
#
#
#
# 4
# A Hollywood rarity - an intelligent action film
#
#
#
#
#
# 5
# Not Your Typical, Brainless Summer Movie
#
#
#
#
#
# 6
# Oozing with originality
#
#
#
#
#
# 7
# Come Back Again!
#
#
#
#
#
# 8
# labyrinth
#
#
#
#
#
# 9
# A deep dive into the human mind, Nolan at his finest
#
#
#
#
#
# 10
# Overrated Mess
#
#
#
#
#
# 11
# Not all the hype suggests but still an enjoyable action thriller built on a good concept and encourages thought afterwards
#
#
#
#
#
# 12
# Matrix light
#
#
#
#
#
# 13
# (De-)Constructing
#
#
#
#
#
# 14
# "...it's never just a dream, is it"?
#
#
#
#
#
# 15
# I have a dream
#
#
#
#
#
# 16
# Christopher Nolan is the Modern Directing Genius
#
#
#
#
#
# 17
# Inception
#
#
#
#
#
# 18
# Dreams within dreams
#
#
#
#
#
# 19
# Mind Boggling.
#
#
#
#
#
# 20
# Overwhelming and impressive movie with frantic action , suspenseful and state-of-art special effects
#
#
#
#
#
# 21
# Mind-boggling...
#
#
#
#
#
# 22
# The ultimate mind-f**k movie? Dream on.
#
#
#
#
#
# 23
# "Take a leap of faith..."
#
#
#
#
#
# 24
# Totally novel story, I found that it took me several viewings to gain a good grasp of it.
#
#
#
#
#
# 25
# What is reality...what is a dream
#
#
#
#
#
# 26
# Too much action, too many stunts...yet still an interesting story idea.
#
#
#
#
#
# 27
# A sci-fi action thriller milestone
#
#
#
#
#
# 28
# Effects-fuelled sci-fi extravaganza
#
#
#
#
#
# 29
# Ultra cool sci-fi
#
#
#
#
#
# 30
# Wow! I Finally Saw It!
#
#
#
#
#
# 31
# a masterpiece
#
#
#
#
#
# 32
# Good? Yes. Groundbreaking? Not really.
#
#
#
#
#
# 33
# Life in reality
#
#
#
#
#
# 34
# Perfect sci-fi, great action and perfect plot for the internet loser generation (like me!)
#
#
#
#
#
# 35
# Blender
#
#
#
#
#
# 36
# "...there's a difference between knowing the path... and walking the path".
#
#
#
#
#
# 37
# Watch the original, but not the sequels.
#
#
#
#
#
# 38
# The Matrix
#
#
#
#
#
# 39
# A cyberpunk classic
#
#
#
#
#
# 40
# A Bit Confusing But A Big F/X Treat
#
#
#
#
#
# 41
# Top-notch movie with impressive production design , marvelous effects and incredible visual designs
#
#
#
#
#
# 42
# A watchable action sci-fi movie that was and still is over-hyped...
#
#
#
#
#
# 43
# Whoa!
#
#
#
#
#
# 44
# "After this, there is no turning back..."
#
#
#
#
#
# 45
# One of the best DVDs out so far, much more than just a movie!
#
#
#
#
#
# 46
# What the hell is the "Matrix?"
#
#
#
#
#
# 47
# One of the greatest achievements in Science-fiction film history
#
#
#
#
#
# 48
# Keanu Reeves in Wonderland
#
#
#
#
#
# 49
# A computer world Alice in Wonderland. Sci-fi greatness!
#
#
#
#
#
# 50
# Awesome sci-fi flick!
#
#
#
#
#
# 51
# Why tack on an ending where everything works out perfectly?!
#
#
#
#
#
# 52
# Often impressive and very beautiful, but less than stellar
#
#
#
#
#
# 53
# Another bloated, overrated space epic
#
#
#
#
#
# 54
# some problems but a few great touches of 2001
#
#
#
#
#
# 55
# Intellectual, Although Sometimes Flawed Science Fiction
#
#
#
#
#
# 56
# Maybe the most spectacular movie of 2014 and one of the best
#
#
#
#
#
# 57
# It doesn't all work, but it is beautiful in its efforts
#
#
#
#
#
# 58
# START PULLING YOUR WEIGHT
#
#
#
#
#
# 59
# Out of this world
#
#
#
#
#
# 60
# "We're not meant to save the world, we're meant to leave it."
#
#
#
#
#
# 61
# Absolutely Brilliant
#
#
#
#
#
# 62
# Interstellar
#
#
#
#
#
# 63
# A journey across the galaxy to save humanity
#
#
#
#
#
# 64
# Great up towards the end...
#
#
#
#
#
# 65
# Disappears up its own black hole.
#
#
#
#
#
# 66
# This is my kind of movie, Sci-Fi with a good story and lots of action.
#
#
#
#
#
# 67
# Interstellar is quite an intriguing space movie requiring some attention to the narrative
#
#
#
#
#
# 68
# Emotionally captivating and intellectually challenging
#
#
#
#
#
# 69
# Absolutely thrilling! A can't miss movie!
#
#
#
#
#
# 70
# Dissymmetries, sight
#
#
#
#
#
# 71
# Worm-Holes ? What About Plot Holes ?
#
#
#
#
#
# 72
# Sometimes Dull and Overwritten but Worth a "Watch"
#
#
#
#
#
# 73
# Long, dull and WAY overpraised
#
#
#
#
#
# 74
# Gone To Earth
#
#
#
#
#
# 75
# When Earth Can No Longer Be Your Home
#
#
#
#
#
# 76
# The world loves it, though I still think the original "Iron Man", "Thor" and "Captain America" were my favorites.
#
#
#
#
#
# 77
# Not 100% perfect but still an outstanding film in so many ways
#
#
#
#
#
# 78
# Wanted to hate it, ended up loving it
#
#
#
#
#
# 79
# A Gem of an Action Movie
#
#
#
#
#
# 80
# Avengers vs TDKR
#
#
#
#
#
# 81
# I'm Too Old for This!
#
#
#
#
#
# 82
# New York Geography
#
#
#
#
#
# 83
# A success yes, but not really on a groundbreaking level
#
#
#
#
#
# 84
# Avengers Assemble at once
#
#
#
#
#
# 85
# Excellent Adventure
#
#
#
#
#
# 86
# Consistently enjoyable effects and noise with the right amount of fun mixed in
#
#
#
#
#
# 87
# If they can't save the box office, they sure as hell will avenge it
#
#
#
#
#
# 88
# "The world has gotten stranger than you even know."
#
#
#
#
#
# 89
# Charlie Chaplin meets Lucy meets Jules
#
#
#
#
#
# 90
# Great Movie... But Not That Great
#
#
#
#
#
# 91
# Avengers Assemble
#
#
#
#
#
# 92
# Avengers Assemble
#
#
#
#
#
# 93
# More superheroes...
#
#
#
#
#
# 94
# What a load of Chitauri.
#
#
#
#
#
# 95
# "We need a plan of attack." ... "I have a plan: attack!"
#
#
#
#
#
# 96
# 'Humans are unruly, and for that reason they cannot be ruled.'
#
#
#
#
#
# 97
# Fun, and great characters and dialog first and foremost
#
#
#
#
#
# 98
# The Avengers is a nearly excellent first movie featuring Marvel's Earth's Mightiest Heroes
#
#
#
#
#
# 99
# A great blockbuster
#
#
#
#
#
# 100
# Marvel Comic heroes to the rescue!!
#
#
#
#
#
# 101
# Some very interesting plot twists and originality, though it's a bit grim and lifeless
#
#
#
#
#
# 102
# Imperfect but fascinating
#
#
#
#
#
# 103
# A film that cheats the viewer - and I hated it for that
#
#
#
#
#
# 104
# Obsession and Revenge
#
#
#
#
#
# 105
# A Film with Intellect
#
#
#
#
#
# 106
# fascinating
#
#
#
#
#
# 107
# So glad this movie did not stay an illusion...
#
#
#
#
#
# 108
# A Great Tale of Rivalry, Obsession, Revenge and Sacrifice
#
#
#
#
#
# 109
# A very well told story despite the lack of shine in the final reveal (spoilers)
#
#
#
#
#
# 110
# (Magic) Layers
#
#
#
#
#
# 111
# "It is very rare to see... real magic."
#
#
#
#
#
# 112
# Batman and Alfred (outside Gotham) meet Wolverine
#
#
#
#
#
# 113
# Give This Film Time to Sink In...
#
#
#
#
#
# 114
# The Prestige
#
#
#
#
#
# 115
# Rivalry and obsession in the world of magic
#
#
#
#
#
# 116
# Never ask me about my business.
#
#
#
#
#
# 117
# Just As Intriguing The Second Time, Too!
#
#
#
#
#
# 118
# Imaginative and intriguing crash of wits between two famous magicians
#
#
#
#
#
# 119
# How many times can you double-cross your audience?
#
#
#
#
#
# 120
# In 'magic' it's all about the third act! The Prestige.
#
#
#
#
#
# 121
# Obsession is a young man's game
#
#
#
#
#
# 122
# a basic tale of one-up-manship, but done in a great fashion of professional storytelling and acting
#
#
#
#
#
# 123
# The Prestige was interesting if maybe a little slow to wade through
#
#
#
#
#
# 124
# The Prestige- Don't Need this Type of Honor 1/2*
#
#
#
#
#
# 125
# LOVED the trick with the canary!
#
#
#
#
#
# 126
# So good in so many ways
#
#
#
#
#
# 127
# An '80s classic that never disappoints
#
#
#
#
#
# 128
# Wonderful story Wonderful Michael J Fox
#
#
#
#
#
# 129
# So Much Fun
#
#
#
#
#
# 130
# adorable
#
#
#
#
#
# 131
# Very entertaining film  as slick as it is fun as it is engaging
#
#
#
#
#
# 132
# Marty got Back
#
#
#
#
#
# 133
# "Yeah well, history is gonna change."
#
#
#
#
#
# 134
# Many people may remember Michael J. Fox as Alex Keaton, but I'll always remember him as Marty McFly
#
#
#
#
#
# 135
# Gets Better With Age
#
#
#
#
#
# 136
# Back to the Future
#
#
#
#
#
# 137
# Great sci-fi adventure for all the family
#
#
#
#
#
# 138
# Amusing and commercial success.
#
#
#
#
#
# 139
# Mixed Emotions Looking Back On This Film Today
#
#
#
#
#
# 140
# Great Scott! Strap in for some entertaining time travel...
#
#
#
#
#
# 141
# A film you can watch time and time again.
#
#
#
#
#
# 142
# Great!
#
#
#
#
#
# 143
# Back To The Future, great start to the trilogy, movies in 1985, 1989, and 1990.
#
#
#
#
#
# 144
# Old Man Peabody owned all of this!
#
#
#
#
#
# 145
# After 30 years, the original Back to the Future is still the best of the series!
#
#
#
#
#
# 146
# A time travel movie that never gets old.
#
#
#
#
#
# 147
# Brilliant Scenario!
#
#
#
#
#
# 148
# Good fun
#
#
#
#
#
# 149
# A timeless classic
#
#
#
#
#
# 150
# Zemeckis Flies
#
#
#
#
#
# 151
# Among the best stuff you'll see from DC Comics.
#
#
#
#
#
# 152
# Looks fantastic, but overall I just didn't care for it
#
#
#
#
#
# 153
# unreal Orwellian world
#
#
#
#
#
# 154
# to see it once
#
#
#
#
#
# 155
# Anonymous wants you
#
#
#
#
#
# 156
# Ideas Are Bulletproof and One Man Can Make the Difference
#
#
#
#
#
# 157
# A surprisingly effective social satire within a Hollywood film? It is not perfect but it is very enjoyable for what it does
#
#
#
#
#
# 158
# Behind the mask
#
#
#
#
#
# 159
# "Then you have no fear anymore, you are completely free."
#
#
#
#
#
# 160
# five'll get you ten
#
#
#
#
#
# 161
# One of Those Rare Films to Really Earn a 10
#
#
#
#
#
# 162
# V for Vendetta
#
#
#
#
#
# 163
# An Interesting Dystopia
#
#
#
#
#
# 164
# Intelligent film with political criticism , thrills , action and suspense
#
#
#
#
#
# 165
# V. Good!
#
#
#
#
#
# 166
# "A revolution without dancing is a revolution not worth having."
#
#
#
#
#
# 167
# Superb movie of the graphic novel.
#
#
#
#
#
# 168
# the first excellent film I've seen in 2006
#
#
#
#
#
# 169
# Winston Churchill Flashes No V Sign Here "V For Vendettal **1/2
#
#
#
#
#
# 170
# Exceeds expectations
#
#
#
#
#
# 171
# A revolution is in the grand plan.
#
#
#
#
#
# 172
# Eloquent
#
#
#
#
#
# 173
# Eye for Itself
#
#
#
#
#
# 174
# V for VigilanteStylish and Dark Film with Political Prognosis
#
#
#
#
#
# 175
# Really surprised at how much I liked this, why did it take me so long to watch it?
#
#
#
#
#
# 176
# A bigger, richer sequel that is every bit as fantastic as its predecessor and even surpasses it in some areas
#
#
#
#
#
# 177
# The purest form of action cinema there is
#
#
#
#
#
# 178
# Masterpiece Sci-Fi
#
#
#
#
#
# 179
# Great action and much more
#
#
#
#
#
# 180
# "You can't just go around killing people!"
#
#
#
#
#
# 181
# Here's why it outdoes the original:
#
#
#
#
#
# 182
# Best. Terminator. Movie. Ever.
#
#
#
#
#
# 183
# Terminator 2: Judgement Day
#
#
#
#
#
# 184
# The Terminator is back this time to save John Connor
#
#
#
#
#
# 185
# Many Annoyances, But An Incredible Action Flick
#
#
#
#
#
# 186
# Nail-biting and exhilarating outing with state-of-art special effects
#
#
#
#
#
# 187
# Come with me if you want to live!...
#
#
#
#
#
# 188
# You want incredible action and excitement? No problemo....
#
#
#
#
#
# 189
# surpasses the original
#
#
#
#
#
# 190
# Hasta la vista baby
#
#
#
#
#
# 191
# Over Produced and Over Rated Sequel
#
#
#
#
#
# 192
# I'll be back
#
#
#
#
#
# 193
# An innovative trend-setter
#
#
#
#
#
# 194
# The Best Terminator Movie!!!
#
#
#
#
#
# 195
# Better than the original
#
#
#
#
#
# 196
# Come with me if you want to live.
#
#
#
#
#
# 197
# There's a reason this is so appreciated
#
#
#
#
#
# 198
# He's Baa-aack
#
#
#
#
#
# 199
# An observation
#
#
#
#
#
# 200
# "Back" and better than ever! One of the best sequels in cinematic history.
#
#
#
#
#
# 201
# Considering I am not much of a fan of superhero movies, this one is a success
#
#
#
#
#
# 202
# A Marvel superhero film done with class
#
#
#
#
#
# 203
# Iron Man Eats His Spinach
#
#
#
#
#
# 204
# Scrapheap Challenge is more entertaining
#
#
#
#
#
# 205
# Very Good
#
#
#
#
#
# 206
# RDJ is Iron Man
#
#
#
#
#
# 207
# No Iron! How Ironic!
#
#
#
#
#
# 208
# interesting
#
#
#
#
#
# 209
# How it all began
#
#
#
#
#
# 210
# Entertaining and Totally Overrated in IMDb
#
#
#
#
#
# 211
# Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster
#
#
#
#
#
# 212
# Great performances
#
#
#
#
#
# 213
# "So you're a man who has everything,..., and nothing."
#
#
#
#
#
# 214
# believe it or not, I'd never heard of Iron Man before this movie came out
#
#
#
#
#
# 215
# Far Exceeds The Character's Usual Presentation
#
#
#
#
#
# 216
# Iron Man
#
#
#
#
#
# 217
# A solid introduction to the Iron man character
#
#
#
#
#
# 218
# A Fun Two Hours Of Nonsense
#
#
#
#
#
# 219
# You'll believe an Iron Man can fly!
#
#
#
#
#
# 220
# Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.
#
#
#
#
#
# 221
# supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre
#
#
#
#
#
# 222
# Iron Man is an exciting beginning for the summer movie season
#
#
#
#
#
# 223
# Iron Man Meets its Mettle **1/2
#
#
#
#
#
# 224
# Disappointing script, sparse action scenes
#
#
#
#
#
# 225
# Genuine blockbuster.
#
#
#
#
#
# 226
# Considering I am not much of a fan of superhero movies, this one is a success
#
#
#
#
#
# 227
# A Marvel superhero film done with class
#
#
#
#
#
# 228
# Iron Man Eats His Spinach
#
#
#
#
#
# 229
# Scrapheap Challenge is more entertaining
#
#
#
#
#
# 230
# Very Good
#
#
#
#
#
# 231
# RDJ is Iron Man
#
#
#
#
#
# 232
# No Iron! How Ironic!
#
#
#
#
#
# 233
# interesting
#
#
#
#
#
# 234
# How it all began
#
#
#
#
#
# 235
# Entertaining and Totally Overrated in IMDb
#
#
#
#
#
# 236
# Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster
#
#
#
#
#
# 237
# Great performances
#
#
#
#
#
# 238
# "So you're a man who has everything,..., and nothing."
#
#
#
#
#
# 239
# believe it or not, I'd never heard of Iron Man before this movie came out
#
#
#
#
#
# 240
# Far Exceeds The Character's Usual Presentation
#
#
#
#
#
# 241
# Iron Man
#
#
#
#
#
# 242
# A solid introduction to the Iron man character
#
#
#
#
#
# 243
# A Fun Two Hours Of Nonsense
#
#
#
#
#
# 244
# You'll believe an Iron Man can fly!
#
#
#
#
#
# 245
# Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.
#
#
#
#
#
# 246
# supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre
#
#
#
#
#
# 247
# Iron Man is an exciting beginning for the summer movie season
#
#
#
#
#
# 248
# Iron Man Meets its Mettle **1/2
#
#
#
#
#
# 249
# Disappointing script, sparse action scenes
#
#
#
#
#
# 250
# Genuine blockbuster.

# %%
# ! pip install jupyterthemes
# ! jt -f 32

# %%
reviews
# Out:
# [{'id': 1, 'text': 'Amazingly original...but also a bit overwhelming.'},
#  {'id': 2, 'text': 'A good film, but not as good as the hype'},
#  {'id': 3, 'text': 'Dream Team'},
#  {'id': 4, 'text': 'A Hollywood rarity - an intelligent action film'},
#  {'id': 5, 'text': 'Not Your Typical, Brainless Summer Movie'},
#  {'id': 6, 'text': 'Oozing with originality'},
#  {'id': 7, 'text': 'Come Back Again!'},
#  {'id': 8, 'text': 'labyrinth'},
#  {'id': 9, 'text': 'A deep dive into the human mind, Nolan at his finest'},
#  {'id': 10, 'text': 'Overrated Mess'},
#  {'id': 11,
#   'text': 'Not all the hype suggests but still an enjoyable action thriller built on a good concept and encourages thought afterwards'},
#  {'id': 12, 'text': 'Matrix light'},
#  {'id': 13, 'text': '(De-)Constructing'},
#  {'id': 14, 'text': '"...it\'s never just a dream, is it"?'},
#  {'id': 15, 'text': 'I have a dream'},
#  {'id': 16, 'text': 'Christopher Nolan is the Modern Directing Genius'},
#  {'id': 17, 'text': 'Inception'},
#  {'id': 18, 'text': 'Dreams within dreams'},
#  {'id': 19, 'text': 'Mind Boggling.'},
#  {'id': 20,
#   'text': 'Overwhelming and impressive movie with frantic action , suspenseful and state-of-art special effects'},
#  {'id': 21, 'text': 'Mind-boggling...'},
#  {'id': 22, 'text': 'The ultimate mind-f**k movie? Dream on.'},
#  {'id': 23, 'text': '"Take a leap of faith..."'},
#  {'id': 24,
#   'text': 'Totally novel story, I found that it took me several viewings to gain a good grasp of it.'},
#  {'id': 25, 'text': 'What is reality...what is a dream'},
#  {'id': 26,
#   'text': 'Too much action, too many stunts...yet still an interesting story idea.'},
#  {'id': 27, 'text': 'A sci-fi action thriller milestone'},
#  {'id': 28, 'text': 'Effects-fuelled sci-fi extravaganza'},
#  {'id': 29, 'text': 'Ultra cool sci-fi'},
#  {'id': 30, 'text': 'Wow! I Finally Saw It!'},
#  {'id': 31, 'text': 'a masterpiece'},
#  {'id': 32, 'text': 'Good? Yes. Groundbreaking? Not really.'},
#  {'id': 33, 'text': 'Life in reality'},
#  {'id': 34,
#   'text': 'Perfect sci-fi, great action and perfect plot for the internet loser generation (like me!)'},
#  {'id': 35, 'text': 'Blender'},
#  {'id': 36,
#   'text': '"...there\'s a difference between knowing the path... and walking the path".'},
#  {'id': 37, 'text': 'Watch the original, but not the sequels.'},
#  {'id': 38, 'text': 'The Matrix'},
#  {'id': 39, 'text': 'A cyberpunk classic'},
#  {'id': 40, 'text': 'A Bit Confusing But A Big F/X Treat'},
#  {'id': 41,
#   'text': 'Top-notch movie with impressive production design , marvelous effects and incredible visual designs'},
#  {'id': 42,
#   'text': 'A watchable action sci-fi movie that was and still is over-hyped...'},
#  {'id': 43, 'text': 'Whoa!'},
#  {'id': 44, 'text': '"After this, there is no turning back..."'},
#  {'id': 45,
#   'text': 'One of the best DVDs out so far, much more than just a movie!'},
#  {'id': 46, 'text': 'What the hell is the "Matrix?"'},
#  {'id': 47,
#   'text': 'One of the greatest achievements in Science-fiction film history'},
#  {'id': 48, 'text': 'Keanu Reeves in Wonderland'},
#  {'id': 49, 'text': 'A computer world Alice in Wonderland. Sci-fi greatness!'},
#  {'id': 50, 'text': 'Awesome sci-fi flick!'},
#  {'id': 51,
#   'text': 'Why tack on an ending where everything works out perfectly?!'},
#  {'id': 52,
#   'text': 'Often impressive and very beautiful, but less than stellar'},
#  {'id': 53, 'text': 'Another bloated, overrated space epic'},
#  {'id': 54, 'text': 'some problems but a few great touches of 2001'},
#  {'id': 55, 'text': 'Intellectual, Although Sometimes Flawed Science Fiction'},
#  {'id': 56,
#   'text': 'Maybe the most spectacular movie of 2014 and one of the best'},
#  {'id': 57, 'text': "It doesn't all work, but it is beautiful in its efforts"},
#  {'id': 58, 'text': 'START PULLING YOUR WEIGHT'},
#  {'id': 59, 'text': 'Out of this world'},
#  {'id': 60,
#   'text': '"We\'re not meant to save the world, we\'re meant to leave it."'},
#  {'id': 61, 'text': 'Absolutely Brilliant'},
#  {'id': 62, 'text': 'Interstellar'},
#  {'id': 63, 'text': 'A journey across the galaxy to save humanity'},
#  {'id': 64, 'text': 'Great up towards the end...'},
#  {'id': 65, 'text': 'Disappears up its own black hole.'},
#  {'id': 66,
#   'text': 'This is my kind of movie, Sci-Fi with a good story and lots of action.'},
#  {'id': 67,
#   'text': 'Interstellar is quite an intriguing space movie requiring some attention to the narrative'},
#  {'id': 68, 'text': 'Emotionally captivating and intellectually challenging'},
#  {'id': 69, 'text': "Absolutely thrilling! A can't miss movie!"},
#  {'id': 70, 'text': 'Dissymmetries, sight'},
#  {'id': 71, 'text': 'Worm-Holes ? What About Plot Holes ?'},
#  {'id': 72, 'text': 'Sometimes Dull and Overwritten but Worth a "Watch"'},
#  {'id': 73, 'text': 'Long, dull and WAY overpraised'},
#  {'id': 74, 'text': 'Gone To Earth'},
#  {'id': 75, 'text': 'When Earth Can No Longer Be Your Home'},
#  {'id': 76,
#   'text': 'The world loves it, though I still think the original "Iron Man", "Thor" and "Captain America" were my favorites.'},
#  {'id': 77,
#   'text': 'Not 100% perfect but still an outstanding film in so many ways'},
#  {'id': 78, 'text': 'Wanted to hate it, ended up loving it'},
#  {'id': 79, 'text': 'A Gem of an Action Movie'},
#  {'id': 80, 'text': 'Avengers vs TDKR'},
#  {'id': 81, 'text': "I'm Too Old for This!"},
#  {'id': 82, 'text': 'New York Geography'},
#  {'id': 83, 'text': 'A success yes, but not really on a groundbreaking level'},
#  {'id': 84, 'text': 'Avengers Assemble at once'},
#  {'id': 85, 'text': 'Excellent Adventure'},
#  {'id': 86,
#   'text': 'Consistently enjoyable effects and noise with the right amount of fun mixed in'},
#  {'id': 87,
#   'text': "If they can't save the box office, they sure as hell will avenge it"},
#  {'id': 88, 'text': '"The world has gotten stranger than you even know."'},
#  {'id': 89, 'text': 'Charlie Chaplin meets Lucy meets Jules'},
#  {'id': 90, 'text': 'Great Movie... But Not That Great'},
#  {'id': 91, 'text': 'Avengers Assemble'},
#  {'id': 92, 'text': 'Avengers Assemble'},
#  {'id': 93, 'text': 'More superheroes...'},
#  {'id': 94, 'text': 'What a load of Chitauri.'},
#  {'id': 95,
#   'text': '"We need a plan of attack." ... "I have a plan: attack!"'},
#  {'id': 96,
#   'text': "'Humans are unruly, and for that reason they cannot be ruled.'"},
#  {'id': 97, 'text': 'Fun, and great characters and dialog first and foremost'},
#  {'id': 98,
#   'text': "The Avengers is a nearly excellent first movie featuring Marvel's Earth's Mightiest Heroes"},
#  {'id': 99, 'text': 'A great blockbuster'},
#  {'id': 100, 'text': 'Marvel Comic heroes to the rescue!!'},
#  {'id': 101,
#   'text': "Some very interesting plot twists and originality, though it's a bit grim and lifeless"},
#  {'id': 102, 'text': 'Imperfect but fascinating'},
#  {'id': 103,
#   'text': 'A film that cheats the viewer - and I hated it for that'},
#  {'id': 104, 'text': 'Obsession and Revenge'},
#  {'id': 105, 'text': 'A Film with Intellect'},
#  {'id': 106, 'text': 'fascinating'},
#  {'id': 107, 'text': 'So glad this movie did not stay an illusion...'},
#  {'id': 108,
#   'text': 'A Great Tale of Rivalry, Obsession, Revenge and Sacrifice'},
#  {'id': 109,
#   'text': 'A very well told story despite the lack of shine in the final reveal (spoilers)'},
#  {'id': 110, 'text': '(Magic) Layers'},
#  {'id': 111, 'text': '"It is very rare to see... real magic."'},
#  {'id': 112, 'text': 'Batman and Alfred (outside Gotham) meet Wolverine'},
#  {'id': 113, 'text': 'Give This Film Time to Sink In...'},
#  {'id': 114, 'text': 'The Prestige'},
#  {'id': 115, 'text': 'Rivalry and obsession in the world of magic'},
#  {'id': 116, 'text': 'Never ask me about my business.'},
#  {'id': 117, 'text': 'Just As Intriguing The Second Time, Too!'},
#  {'id': 118,
#   'text': 'Imaginative and intriguing crash of wits between two famous magicians'},
#  {'id': 119, 'text': 'How many times can you double-cross your audience?'},
#  {'id': 120, 'text': "In 'magic' it's all about the third act! The Prestige."},
#  {'id': 121, 'text': "Obsession is a young man's game"},
#  {'id': 122,
#   'text': 'a basic tale of one-up-manship, but done in a great fashion of professional storytelling and acting'},
#  {'id': 123,
#   'text': 'The Prestige was interesting if maybe a little slow to wade through'},
#  {'id': 124, 'text': "The Prestige- Don't Need this Type of Honor 1/2*"},
#  {'id': 125, 'text': 'LOVED the trick with the canary!'},
#  {'id': 126, 'text': 'So good in so many ways'},
#  {'id': 127, 'text': "An '80s classic that never disappoints"},
#  {'id': 128, 'text': 'Wonderful story Wonderful Michael J Fox'},
#  {'id': 129, 'text': 'So Much Fun'},
#  {'id': 130, 'text': 'adorable'},
#  {'id': 131,
#   'text': 'Very entertaining film \x96 as slick as it is fun as it is engaging'},
#  {'id': 132, 'text': 'Marty got Back'},
#  {'id': 133, 'text': '"Yeah well, history is gonna change."'},
#  {'id': 134,
#   'text': "Many people may remember Michael J. Fox as Alex Keaton, but I'll always remember him as Marty McFly"},
#  {'id': 135, 'text': 'Gets Better With Age'},
#  {'id': 136, 'text': 'Back to the Future'},
#  {'id': 137, 'text': 'Great sci-fi adventure for all the family'},
#  {'id': 138, 'text': 'Amusing and commercial success.'},
#  {'id': 139, 'text': 'Mixed Emotions Looking Back On This Film Today'},
#  {'id': 140,
#   'text': 'Great Scott! Strap in for some entertaining time travel...'},
#  {'id': 141, 'text': 'A film you can watch time and time again.'},
#  {'id': 142, 'text': 'Great!'},
#  {'id': 143,
#   'text': 'Back To The Future, great start to the trilogy, movies in 1985, 1989, and 1990.'},
#  {'id': 144, 'text': 'Old Man Peabody owned all of this!'},
#  {'id': 145,
#   'text': 'After 30 years, the original Back to the Future is still the best of the series!'},
#  {'id': 146, 'text': 'A time travel movie that never gets old.'},
#  {'id': 147, 'text': 'Brilliant Scenario!'},
#  {'id': 148, 'text': 'Good fun'},
#  {'id': 149, 'text': 'A timeless classic'},
#  {'id': 150, 'text': 'Zemeckis Flies'},
#  {'id': 151, 'text': "Among the best stuff you'll see from DC Comics."},
#  {'id': 152, 'text': "Looks fantastic, but overall I just didn't care for it"},
#  {'id': 153, 'text': 'unreal Orwellian world'},
#  {'id': 154, 'text': 'to see it once'},
#  {'id': 155, 'text': 'Anonymous wants you'},
#  {'id': 156,
#   'text': 'Ideas Are Bulletproof and One Man Can Make the Difference'},
#  {'id': 157,
#   'text': 'A surprisingly effective social satire within a Hollywood film? It is not perfect but it is very enjoyable for what it does'},
#  {'id': 158, 'text': 'Behind the mask'},
#  {'id': 159,
#   'text': '"Then you have no fear anymore, you are completely free."'},
#  {'id': 160, 'text': "five'll get you ten"},
#  {'id': 161, 'text': 'One of Those Rare Films to Really Earn a 10'},
#  {'id': 162, 'text': 'V for Vendetta'},
#  {'id': 163, 'text': 'An Interesting Dystopia'},
#  {'id': 164,
#   'text': 'Intelligent film with political criticism , thrills , action and suspense'},
#  {'id': 165, 'text': 'V. Good!'},
#  {'id': 166,
#   'text': '"A revolution without dancing is a revolution not worth having."'},
#  {'id': 167, 'text': 'Superb movie of the graphic novel.'},
#  {'id': 168, 'text': "the first excellent film I've seen in 2006"},
#  {'id': 169,
#   'text': 'Winston Churchill Flashes No V Sign Here "V For Vendettal **1/2'},
#  {'id': 170, 'text': 'Exceeds expectations'},
#  {'id': 171, 'text': 'A revolution is in the grand plan.'},
#  {'id': 172, 'text': 'Eloquent'},
#  {'id': 173, 'text': 'Eye for Itself'},
#  {'id': 174,
#   'text': 'V for Vigilante\x85Stylish and Dark Film with Political Prognosis'},
#  {'id': 175,
#   'text': 'Really surprised at how much I liked this, why did it take me so long to watch it?'},
#  {'id': 176,
#   'text': 'A bigger, richer sequel that is every bit as fantastic as its predecessor and even surpasses it in some areas'},
#  {'id': 177, 'text': 'The purest form of action cinema there is'},
#  {'id': 178, 'text': 'Masterpiece Sci-Fi'},
#  {'id': 179, 'text': 'Great action and much more'},
#  {'id': 180, 'text': '"You can\'t just go around killing people!"'},
#  {'id': 181, 'text': "Here's why it outdoes the original:"},
#  {'id': 182, 'text': 'Best. Terminator. Movie. Ever.'},
#  {'id': 183, 'text': 'Terminator 2: Judgement Day'},
#  {'id': 184,
#   'text': 'The Terminator is back\x85 this time to save John Connor'},
#  {'id': 185, 'text': 'Many Annoyances, But An Incredible Action Flick'},
#  {'id': 186,
#   'text': 'Nail-biting and exhilarating outing with state-of-art special effects'},
#  {'id': 187, 'text': 'Come with me if you want to live!...'},
#  {'id': 188,
#   'text': 'You want incredible action and excitement? No problemo....'},
#  {'id': 189, 'text': 'surpasses the original'},
#  {'id': 190, 'text': 'Hasta la vista baby'},
#  {'id': 191, 'text': 'Over Produced and Over Rated Sequel'},
#  {'id': 192, 'text': "I'll be back"},
#  {'id': 193, 'text': 'An innovative trend-setter'},
#  {'id': 194, 'text': 'The Best Terminator Movie!!!'},
#  {'id': 195, 'text': 'Better than the original'},
#  {'id': 196, 'text': 'Come with me if you want to live.'},
#  {'id': 197, 'text': "There's a reason this is so appreciated"},
#  {'id': 198, 'text': "He's Baa-aack"},
#  {'id': 199, 'text': 'An observation'},
#  {'id': 200,
#   'text': '"Back" and better than ever! One of the best sequels in cinematic history.'},
#  {'id': 201,
#   'text': 'Considering I am not much of a fan of superhero movies, this one is a success'},
#  {'id': 202, 'text': 'A Marvel superhero film done with class'},
#  {'id': 203, 'text': 'Iron Man Eats His Spinach'},
#  {'id': 204, 'text': 'Scrapheap Challenge is more entertaining'},
#  {'id': 205, 'text': 'Very Good'},
#  {'id': 206, 'text': 'RDJ is Iron Man'},
#  {'id': 207, 'text': 'No Iron! How Ironic!'},
#  {'id': 208, 'text': 'interesting'},
#  {'id': 209, 'text': 'How it all began'},
#  {'id': 210, 'text': 'Entertaining and Totally Overrated in IMDb'},
#  {'id': 211,
#   'text': 'Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster'},
#  {'id': 212, 'text': 'Great performances'},
#  {'id': 213,
#   'text': '"So you\'re a man who has everything,..., and nothing."'},
#  {'id': 214,
#   'text': "believe it or not, I'd never heard of Iron Man before this movie came out"},
#  {'id': 215, 'text': "Far Exceeds The Character's Usual Presentation"},
#  {'id': 216, 'text': 'Iron Man'},
#  {'id': 217, 'text': 'A solid introduction to the Iron man character'},
#  {'id': 218, 'text': 'A Fun Two Hours Of Nonsense'},
#  {'id': 219, 'text': "You'll believe an Iron Man can fly!"},
#  {'id': 220,
#   'text': 'Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.'},
#  {'id': 221,
#   'text': "supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre"},
#  {'id': 222,
#   'text': 'Iron Man is an exciting beginning for the summer movie season'},
#  {'id': 223, 'text': 'Iron Man Meets its Mettle **1/2'},
#  {'id': 224, 'text': 'Disappointing script, sparse action scenes'},
#  {'id': 225, 'text': 'Genuine blockbuster.'},
#  {'id': 226,
#   'text': 'Considering I am not much of a fan of superhero movies, this one is a success'},
#  {'id': 227, 'text': 'A Marvel superhero film done with class'},
#  {'id': 228, 'text': 'Iron Man Eats His Spinach'},
#  {'id': 229, 'text': 'Scrapheap Challenge is more entertaining'},
#  {'id': 230, 'text': 'Very Good'},
#  {'id': 231, 'text': 'RDJ is Iron Man'},
#  {'id': 232, 'text': 'No Iron! How Ironic!'},
#  {'id': 233, 'text': 'interesting'},
#  {'id': 234, 'text': 'How it all began'},
#  {'id': 235, 'text': 'Entertaining and Totally Overrated in IMDb'},
#  {'id': 236,
#   'text': 'Far from a brilliant film but still a bright, breezy and enjoyable summer blockbuster'},
#  {'id': 237, 'text': 'Great performances'},
#  {'id': 238,
#   'text': '"So you\'re a man who has everything,..., and nothing."'},
#  {'id': 239,
#   'text': "believe it or not, I'd never heard of Iron Man before this movie came out"},
#  {'id': 240, 'text': "Far Exceeds The Character's Usual Presentation"},
#  {'id': 241, 'text': 'Iron Man'},
#  {'id': 242, 'text': 'A solid introduction to the Iron man character'},
#  {'id': 243, 'text': 'A Fun Two Hours Of Nonsense'},
#  {'id': 244, 'text': "You'll believe an Iron Man can fly!"},
#  {'id': 245,
#   'text': 'Stan Lee must have a big grin on his face, seeing his Iron Man on the big screen.'},
#  {'id': 246,
#   'text': "supreme comic-book entertainment; it's also more jaded, and funnier, than most in its genre"},
#  {'id': 247,
#   'text': 'Iron Man is an exciting beginning for the summer movie season'},
#  {'id': 248, 'text': 'Iron Man Meets its Mettle **1/2'},
#  {'id': 249, 'text': 'Disappointing script, sparse action scenes'},
#  {'id': 250, 'text': 'Genuine blockbuster.'}]

# %%
reviews[0].values()
# Out:
# dict_values([1, 'Amazingly original...but also a bit overwhelming.'])

# %% [markdown]
# ## Create a Cognitive Services Resource
#
# To analyze the text in these reviews, you can use the **Text Analytics** cognitive service. To use this, you need to provision either a **Text Analytics** or **Cognitive Services** resource in your Azure subscription (Use a Text Analytics resource if this is the only service you plan to use or you want to track its usage separately; otherwise you can use a Cognitive Services resource to combine the Text Analytics service with other cognitive services - enabling developers to use a single endpoint and key to access them.)
#
# If you don't already have one, use the following steps to create a **Cognitive Services** resource in your Azure subscription:
#
# 1. In another browser tab, open the Azure portal at https://portal.azure.com, signing in with your Microsoft account.
# 2. Click the **&#65291;Create a resource** button, search for *Cognitive Services*, and create a **Cognitive Services** resource with the following settings:
#     - **Name**: *Enter a unique name*.
#     - **Subscription**: *Your Azure subscription*.
#     - **Location**: *Any available location*.
#     - **Pricing tier**: S0
#     - **Resource group**: *Create a resource group with a unique name*.
# 3. Wait for deployment to complete. Then go to your cognitive services resource, and on the **Overview** page, click the link to manage the keys for the service. You will need the endpoint and keys to connect to your cognitive services resource from client applications.
#
# ### Get the Key and Endpoint for your Cognitive Services resource
#
# To use your cognitive services resource, client applications need its  endpoint and authentication key:
#
# 1. In the Azure portal, on the **Keys and Endpoint** page for your cognitive service resource, copy the **Key1** for your resource and paste it in the code below, replacing **YOUR_COG_KEY**.
# 2. Copy the **endpoint** for your resource and and paste it in the code below, replacing **YOUR_COG_ENDPOINT**.
# 3. Run the code in the cell below by clicking its green <span style="color:green">&#9655</span> button.

# %%
# cog_key = 'YOUR_COG_KEY'
# cog_endpoint = 'YOUR_COG_ENDPOINT'

cog_key = '653de0e254bf40e093e18c372450f247'
cog_endpoint = 'https://cognitive-services-ai1006.cognitiveservices.azure.com/'


print('Ready to use cognitive services at {} using key {}'.format(cog_endpoint, cog_key))
# Out:
# Ready to use cognitive services at https://cognitive-services-ai1006.cognitiveservices.azure.com/ using key 653de0e254bf40e093e18c372450f247

# %%
# ! pip install azure-cognitiveservices-language-textanalytics

# %%
import os
from azure.cognitiveservices.language.textanalytics import TextAnalyticsClient
from msrest.authentication import CognitiveServicesCredentials

# Get a client for your text analytics cognitive service resource
text_analytics_client = TextAnalyticsClient(endpoint=cog_endpoint,
                                            credentials=CognitiveServicesCredentials(cog_key))

# # Analyze the reviews you read from the /data/reviews folder earlier
# language_analysis = text_analytics_client.detect_language(documents=reviews)

# # print detected language details for each review
# for review_num in range(len(reviews)):
#     # print the review id
#     print(reviews[review_num]['id'])

#     # Get the language details for this review
#     lang = language_analysis.documents[review_num].detected_languages[0]
#     print(' - Language: {}\n - Code: {}\n - Score: {}\n'.format(lang.name, lang.iso6391_name, lang.score))

#     # Add the detected language code to the collection of reviews (so we can do further analysis)
#     reviews[review_num]["language"] = lang.iso6391_name

# %% [markdown]
# ## Extract Key Phrases
#
# Now you can analyze the text in the customer reviews to identify key phrases that give some indication of the main talking points.

# %%
# # # Use the client and reviews you created in the previous code cell to get key phrases
# key_phrase_analysis = text_analytics_client.key_phrases(documents=reviews)

# # print key phrases for each review
# for review_num in range(len(reviews)):
#     # print the review id
#     print(reviews[review_num]['id'])

#     # Get the key phrases in this review
#     print('\nKey Phrases:')
#     key_phrases = key_phrase_analysis.documents[review_num].key_phrases
#     # Print each key phrase
#     for key_phrase in key_phrases:
#         print('\t', key_phrase)
#     print('\n')

# %% [markdown]
# The key phrases can help you gain an understanding of the most important talking points in each review. For example, a review containing a phrase "helpful staff" or "poor service" can give you an indication of some of the main concerns of the reviewer.
#
# ## Determine Sentiment
#
# It might be useful to classify the reviews as *positive* or *negative* based on a *sentiment score*. Again, you can use the Text Analytics service to do this.

# %%
# Use the client and reviews you created previously to get sentiment scores
sentiment_analysis = text_analytics_client.sentiment(documents=reviews)
sen = []

# Print the results for each review
for review_num in range(len(reviews)):
    
#     print(review_num)
#     # Get the sentiment score for this review
    sentiment_score = sentiment_analysis.documents[review_num].score

    # classifiy 'positive' if more than 0.5, 
    if sentiment_score < 0.5:
        sentiment = 'negative'
    else:
        sentiment = 'positive'
        
    sen.append(sentiment)
    

    # print file name and sentiment
    print('{} : {} ({})'.format(reviews[review_num]['id'], sentiment, sentiment_score))
# Out:
# 1 : positive (0.9361017346382141)
# 2 : positive (0.9527643918991089)
# 3 : positive (0.5)
# 4 : positive (0.9383746385574341)
# 5 : positive (0.5)
# 6 : positive (0.5)
# 7 : positive (0.7591207027435303)
# 8 : positive (0.5)
# 9 : positive (0.9492577314376831)
# 10 : positive (0.5)
# 11 : positive (0.9733927249908447)
# 12 : positive (0.5)
# 13 : positive (0.5)
# 14 : negative (0.23572972416877747)
# 15 : positive (0.9365134239196777)
# 16 : positive (0.5)
# 17 : positive (0.5)
# 18 : positive (0.9083166718482971)
# 19 : positive (0.5)
# 20 : positive (0.7546173334121704)
# 21 : positive (0.5)
# 22 : positive (0.9878386855125427)
# 23 : positive (0.9428151845932007)
# 24 : positive (0.9699159860610962)
# 25 : positive (0.9148432612419128)
# 26 : negative (0.22896331548690796)
# 27 : positive (0.5)
# 28 : positive (0.5)
# 29 : positive (0.8750526905059814)
# 30 : positive (0.9959577322006226)
# 31 : positive (0.5)
# 32 : positive (0.9295440316200256)
# 33 : negative (0.3126426339149475)
# 34 : positive (0.8407241702079773)
# 35 : positive (0.5)
# 36 : positive (0.5)
# 37 : positive (0.5)
# 38 : positive (0.5)
# 39 : positive (0.5)
# 40 : positive (0.5)
# 41 : positive (0.9936245679855347)
# 42 : positive (0.9492479562759399)
# 43 : positive (0.5)
# 44 : positive (0.7591210007667542)
# 45 : positive (0.9274375438690186)
# 46 : negative (0.21979418396949768)
# 47 : positive (0.9071245789527893)
# 48 : positive (0.5)
# 49 : positive (0.5)
# 50 : positive (0.9364357590675354)
# 51 : negative (0.228037029504776)
# 52 : positive (0.8784112930297852)
# 53 : negative (0.20355486869812012)
# 54 : negative (0.08908933401107788)
# 55 : positive (0.5)
# 56 : positive (0.9710230231285095)
# 57 : negative (0.2270869016647339)
# 58 : positive (0.5)
# 59 : positive (0.8006901741027832)
# 60 : negative (0.19134074449539185)
# 61 : positive (0.9699022769927979)
# 62 : positive (0.5)
# 63 : positive (0.5)
# 64 : positive (0.907401978969574)
# 65 : positive (0.5)
# 66 : positive (0.9891567230224609)
# 67 : positive (0.9462130069732666)
# 68 : positive (0.8087915778160095)
# 69 : positive (0.9933284521102905)
# 70 : positive (0.5)
# 71 : positive (0.5)
# 72 : positive (0.824845552444458)
# 73 : negative (0.16571620106697083)
# 74 : positive (0.7685481309890747)
# 75 : positive (0.5)
# 76 : positive (0.9944688081741333)
# 77 : positive (0.8088797330856323)
# 78 : negative (0.15404292941093445)
# 79 : positive (0.5)
# 80 : positive (0.5)
# 81 : negative (0.21781021356582642)
# 82 : positive (0.5)
# 83 : positive (0.5)
# 84 : positive (0.5)
# 85 : positive (0.9720777273178101)
# 86 : positive (0.9961742162704468)
# 87 : negative (0.12835091352462769)
# 88 : negative (0.24196112155914307)
# 89 : positive (0.5)
# 90 : positive (0.9853818416595459)
# 91 : positive (0.5)
# 92 : positive (0.5)
# 93 : positive (0.5)
# 94 : positive (0.5)
# 95 : negative (0.04204198718070984)
# 96 : negative (0.05774921178817749)
# 97 : positive (0.9845580458641052)
# 98 : positive (0.9485361576080322)
# 99 : positive (0.9573339223861694)
# 100 : positive (0.5)
# 101 : negative (0.23134934902191162)
# 102 : negative (0.22871875762939453)
# 103 : negative (0.07253023982048035)
# 104 : positive (0.5)
# 105 : positive (0.5)
# 106 : positive (0.9699022769927979)
# 107 : positive (0.942528247833252)
# 108 : positive (0.5)
# 109 : positive (0.9383810758590698)
# 110 : positive (0.5)
# 111 : positive (0.9011504054069519)
# 112 : positive (0.5)
# 113 : positive (0.5)
# 114 : positive (0.5)
# 115 : positive (0.9591857194900513)
# 116 : positive (0.5)
# 117 : positive (0.9115961790084839)
# 118 : positive (0.913200855255127)
# 119 : positive (0.8315848112106323)
# 120 : positive (0.9697983860969543)
# 121 : positive (0.5)
# 122 : positive (0.9715977907180786)
# 123 : positive (0.7609326839447021)
# 124 : positive (0.5)
# 125 : positive (0.9091416597366333)
# 126 : positive (0.89991295337677)
# 127 : positive (0.5)
# 128 : positive (0.9136527180671692)
# 129 : positive (0.5)
# 130 : positive (0.9699022769927979)
# 131 : positive (0.9957764744758606)
# 132 : positive (0.5)
# 133 : negative (0.23687651753425598)
# 134 : positive (0.5)
# 135 : positive (0.8868534564971924)
# 136 : negative (0.15752893686294556)
# 137 : positive (0.968949556350708)
# 138 : positive (0.989958643913269)
# 139 : negative (0.2185841202735901)
# 140 : positive (0.9872878789901733)
# 141 : positive (0.9030886888504028)
# 142 : positive (0.9699022769927979)
# 143 : negative (0.09212470054626465)
# 144 : positive (0.784489631652832)
# 145 : negative (0.14618656039237976)
# 146 : positive (0.5)
# 147 : positive (0.9720777273178101)
# 148 : positive (0.9768028855323792)
# 149 : positive (0.972540020942688)
# 150 : positive (0.5)
# 151 : positive (0.8990051746368408)
# 152 : positive (0.8760915994644165)
# 153 : positive (0.7615243196487427)
# 154 : positive (0.7223796248435974)
# 155 : positive (0.5)
# 156 : positive (0.5)
# 157 : positive (0.9993342757225037)
# 158 : positive (0.5)
# 159 : positive (0.8938536047935486)
# 160 : positive (0.5)
# 161 : positive (0.5)
# 162 : positive (0.5)
# 163 : positive (0.5)
# 164 : positive (0.9470252394676208)
# 165 : positive (0.5)
# 166 : negative (0.10928449034690857)
# 167 : positive (0.9572218656539917)
# 168 : positive (0.9133591651916504)
# 169 : positive (0.5)
# 170 : positive (0.5)
# 171 : positive (0.847459077835083)
# 172 : positive (0.9699022769927979)
# 173 : positive (0.7747650146484375)
# 174 : positive (0.9737775325775146)
# 175 : positive (0.9245305061340332)
# 176 : positive (0.9984723329544067)
# 177 : positive (0.9632021188735962)
# 178 : positive (0.5)
# 179 : positive (0.9392960071563721)
# 180 : negative (0.16859373450279236)
# 181 : positive (0.9320019483566284)
# 182 : positive (0.9987555742263794)
# 183 : positive (0.5)
# 184 : positive (0.5)
# 185 : positive (0.5)
# 186 : positive (0.8652924299240112)
# 187 : negative (0.19658160209655762)
# 188 : positive (0.8359529972076416)
# 189 : positive (0.9314355850219727)
# 190 : positive (0.5)
# 191 : positive (0.5)
# 192 : positive (0.8405475616455078)
# 193 : positive (0.9159331321716309)
# 194 : positive (0.5)
# 195 : positive (0.9314355850219727)
# 196 : negative (0.19658160209655762)
# 197 : positive (0.9648100137710571)
# 198 : positive (0.7417173385620117)
# 199 : positive (0.5)
# 200 : positive (0.9602386951446533)
# 201 : positive (0.9849178791046143)
# 202 : positive (0.5)
# 203 : positive (0.5)
# 204 : positive (0.9438564777374268)
# 205 : positive (0.9699022769927979)
# 206 : positive (0.5)
# 207 : positive (0.8224130868911743)
# 208 : positive (0.9699022769927979)
# 209 : positive (0.7816747426986694)
# 210 : positive (0.8993266224861145)
# 211 : negative (0.2489960491657257)
# 212 : positive (0.9034965634346008)
# 213 : positive (0.5)
# 214 : positive (0.5)
# 215 : positive (0.5)
# 216 : positive (0.5)
# 217 : positive (0.5)
# 218 : positive (0.5)
# 219 : positive (0.5)
# 220 : positive (0.5)
# 221 : positive (0.9906347990036011)
# 222 : positive (0.9457712173461914)
# 223 : positive (0.5)
# 224 : negative (0.10911491513252258)
# 225 : positive (0.9720777273178101)
# 226 : positive (0.9849178791046143)
# 227 : positive (0.5)
# 228 : positive (0.5)
# 229 : positive (0.9438564777374268)
# 230 : positive (0.9699022769927979)
# 231 : positive (0.5)
# 232 : positive (0.8224130868911743)
# 233 : positive (0.9699022769927979)
# 234 : positive (0.7816747426986694)
# 235 : positive (0.8993266224861145)
# 236 : negative (0.2489960491657257)
# 237 : positive (0.9034965634346008)
# 238 : positive (0.5)
# 239 : positive (0.5)
# 240 : positive (0.5)
# 241 : positive (0.5)
# 242 : positive (0.5)
# 243 : positive (0.5)
# 244 : positive (0.5)
# 245 : positive (0.5)
# 246 : positive (0.9906347990036011)
# 247 : positive (0.9457712173461914)
# 248 : positive (0.5)
# 249 : negative (0.10911491513252258)
# 250 : positive (0.9720777273178101)

# %%
sentimental_df['sentiments'] = sen

# %%
sentimental_df.to_csv (r'D:\Sentiment analytics\Assignment3\science data.csv', index = None, header=True) 
sentimental_df.head(20)
# Out:
#     Sr.no       name  year movie_rated run_length  \
# 0       1  Inception  2010       PG-13   2h 28min
# 1       2  Inception  2010       PG-13   2h 28min
# 2       3  Inception  2010       PG-13   2h 28min
# 3       4  Inception  2010       PG-13   2h 28min
# 4       5  Inception  2010       PG-13   2h 28min
# 5       6  Inception  2010       PG-13   2h 28min
# 6       7  Inception  2010       PG-13   2h 28min
# 7       8  Inception  2010       PG-13   2h 28min
# 8       9  Inception  2010       PG-13   2h 28min
# 9      10  Inception  2010       PG-13   2h 28min
# 10     11  Inception  2010       PG-13   2h 28min
# 11     12  Inception  2010       PG-13   2h 28min
# 12     13  Inception  2010       PG-13   2h 28min
# 13     14  Inception  2010       PG-13   2h 28min
# 14     15  Inception  2010       PG-13   2h 28min
# 15     16  Inception  2010       PG-13   2h 28min
# 16     17  Inception  2010       PG-13   2h 28min
# 17     18  Inception  2010       PG-13   2h 28min
# 18     19  Inception  2010       PG-13   2h 28min
# 19     20  Inception  2010       PG-13   2h 28min
#
#                          genres        release_date  IMDB_rating  num_raters  \
# 0   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 1   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 2   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 3   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 4   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 5   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 6   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 7   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 8   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 9   Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 10  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 11  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 12  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 13  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 14  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 15  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 16  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 17  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 18  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
# 19  Action; Adventure; Sci-Fi;   16 July 2010 (USA)          8.8     1981688
#
#     num_reviews                                         review_url  \
# 0          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 1          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 2          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 3          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 4          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 5          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 6          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 7          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 8          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 9          3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 10         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 11         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 12         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 13         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 14         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 15         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 16         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 17         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 18         3820  https://www.imdb.com/title/tt1375666/reviews/_...
# 19         3820  https://www.imdb.com/title/tt1375666/reviews/_...
#
#                                             image_Url  rating  \
# 0   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 1   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       7
# 2   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       9
# 3   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 4   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
# 5   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       9
# 6   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...      10
# 7   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
# 8   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 9   https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       6
# 10  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       0
# 11  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...      10
# 12  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...      10
# 13  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...      10
# 14  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 15  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 16  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       8
# 17  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...      10
# 18  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       2
# 19  https://resizing.flixster.com/8X8J8sNXmCWDBaxo...       7
#
#                                               keyword review_date  \
# 0   Amazingly original...but also a bit overwhelming.   02-Dec-10
# 1            A good film, but not as good as the hype   05-Mar-11
# 2                                          Dream Team   21-Jul-10
# 3     A Hollywood rarity - an intelligent action film   04-Aug-16
# 4            Not Your Typical, Brainless Summer Movie   23-Jul-10
# 5                             Oozing with originality   01-Oct-13
# 6                                    Come Back Again!   31-Jul-10
# 7                                           labyrinth   31-Dec-16
# 8   A deep dive into the human mind, Nolan at his ...   18-Aug-20
# 9                                      Overrated Mess   12-Dec-10
# 10  Not all the hype suggests but still an enjoyab...   02-Aug-10
# 11                                       Matrix light   21-Jul-18
# 12                                  (De-)Constructing   23-Oct-10
# 13               "...it's never just a dream, is it"?   05-Sep-11
# 14                                     I have a dream   17-Jul-10
# 15   Christopher Nolan is the Modern Directing Genius   07-Jan-11
# 16                                          Inception   29-Jul-10
# 17                               Dreams within dreams   15-Apr-11
# 18                                     Mind Boggling.   18-Jun-11
# 19  Overwhelming and impressive movie with frantic...   29-Nov-21
#
#                                                review sentiments
# 0   This review is being written by a 46 year-old ...   positive
# 1   I heard a number of great things about Incepti...   positive
# 2   Watching Inception with its futuristic emphasi...   positive
# 3   Christopher Nolan is a director to be applaude...   positive
# 4   Inception (2010) *** 1/2 (out of 4)The "kiss" ...   positive
# 5   This is a world where people can go into your ...   positive
# 6   If one goes to an art gallery to see a provoca...   positive
# 7   it has the gift to become a personal story. be...   positive
# 8   The word "Inception" will always be associated...   positive
# 9   In the future, the industrial spy Cobb (Leonar...   positive
# 10  The important thing to start out with is to di...   positive
# 11  If you didn't like the Matrix, you might skip ...   positive
# 12  So is it the most clever movie ever made or is...   positive
# 13  Unless you're willing to commit and remain ful...   negative
# 14  So far, Christopher Nolan has not disappointed...   positive
# 15  As I type this, "Inception" is sitting at #6 o...   positive
# 16  From BAFTA and Golden Globe nominated director...   positive
# 17  Often when one is told that a film is amazing ...   positive
# 18  Around 750, the renowned poet of the Tang dyna...   positive
# 19  This stunnning sci-fi thriller Inception (2010...   positive
